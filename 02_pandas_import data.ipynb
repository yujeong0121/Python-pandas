# %% [markdown]
# ### importing CSV Files

# %% [markdown]
# - 헤더 정하기
# - 인덱스 지정하기
# - 원하는 칼럼만 불러오기
# - 칼럼명, 인덱스명 변경하기

# %%
with open("./Course_Materials_Part2/Course_Materials_Part2/Video_Lecture_NBs/titanic.csv") as f:
    text = f.readlines()

# %%
text
# Out:
# ['survived,pclass,sex,age,sibsp,parch,fare,embarked,deck\n',
#  '0,3,male,22.0,1,0,7.25,S,\n',
#  '1,1,female,38.0,1,0,71.2833,C,C\n',
#  '1,3,female,26.0,0,0,7.925,S,\n',
#  '1,1,female,35.0,1,0,53.1,S,C\n',
#  '0,3,male,35.0,0,0,8.05,S,\n',
#  '0,3,male,,0,0,8.4583,Q,\n',
#  '0,1,male,54.0,0,0,51.8625,S,E\n',
#  '0,3,male,2.0,3,1,21.075,S,\n',
#  '1,3,female,27.0,0,2,11.1333,S,\n',
#  '1,2,female,14.0,1,0,30.0708,C,\n',
#  '1,3,female,4.0,1,1,16.7,S,G\n',
#  '1,1,female,58.0,0,0,26.55,S,C\n',
#  '0,3,male,20.0,0,0,8.05,S,\n',
#  '0,3,male,39.0,1,5,31.275,S,\n',
#  '0,3,female,14.0,0,0,7.8542,S,\n',
#  '1,2,female,55.0,0,0,16.0,S,\n',
#  '0,3,male,2.0,4,1,29.125,Q,\n',
#  '1,2,male,,0,0,13.0,S,\n',
#  '0,3,female,31.0,1,0,18.0,S,\n',
#  '1,3,female,,0,0,7.225,C,\n',
#  '0,2,male,35.0,0,0,26.0,S,\n',
#  '1,2,male,34.0,0,0,13.0,S,D\n',
#  '1,3,female,15.0,0,0,8.0292,Q,\n',
#  '1,1,male,28.0,0,0,35.5,S,A\n',
#  '0,3,female,8.0,3,1,21.075,S,\n',
#  '1,3,female,38.0,1,5,31.3875,S,\n',
# ...

# %%
 len(text) # 헤더줄을 포함하여 승객까지 892줄이 있음
# Out:
# 892

# %%
print("Hello \nworld")
# Out:
# Hello
# world

# %%
import pandas as pd

# %% [markdown]
# #### 기본 읽기

# %%
pd.read_csv("./Course_Materials_Part2/Course_Materials_Part2/Video_Lecture_NBs/titanic.csv")
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %% [markdown]
# #### 인덱스 칼럼 정하기

# %%
pd.read_csv("./Course_Materials_Part2/Course_Materials_Part2/Video_Lecture_NBs/titanic.csv", index_col= "pclass")
# Out:
#         survived     sex   age  sibsp  parch     fare embarked deck
# pclass
# 3              0    male  22.0      1      0   7.2500        S  NaN
# 1              1  female  38.0      1      0  71.2833        C    C
# 3              1  female  26.0      0      0   7.9250        S  NaN
# 1              1  female  35.0      1      0  53.1000        S    C
# 3              0    male  35.0      0      0   8.0500        S  NaN
# ...          ...     ...   ...    ...    ...      ...      ...  ...
# 2              0    male  27.0      0      0  13.0000        S  NaN
# 1              1  female  19.0      0      0  30.0000        S    B
# 3              0  female   NaN      1      2  23.4500        S  NaN
# 1              1    male  26.0      0      0  30.0000        C    C
# 3              0    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 8 columns]

# %% [markdown]
# #### 헤더 정하기

# %%
pd.read_csv("./Course_Materials_Part2/Course_Materials_Part2/Video_Lecture_NBs/titanic.csv", header = 0) # header = o is default
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
pd.read_csv("./Course_Materials_Part2/Course_Materials_Part2/Video_Lecture_NBs/titanic.csv", header = 1)
#nan값이 있어서 unnamed가 생김
# Out:
#      0  3    male  22.0  1  0.1     7.25  S Unnamed: 8
# 0    1  1  female  38.0  1    0  71.2833  C          C
# 1    1  3  female  26.0  0    0   7.9250  S        NaN
# 2    1  1  female  35.0  1    0  53.1000  S          C
# 3    0  3    male  35.0  0    0   8.0500  S        NaN
# 4    0  3    male   NaN  0    0   8.4583  Q        NaN
# ..  .. ..     ...   ... ..  ...      ... ..        ...
# 885  0  2    male  27.0  0    0  13.0000  S        NaN
# 886  1  1  female  19.0  0    0  30.0000  S          B
# 887  0  3  female   NaN  1    2  23.4500  S        NaN
# 888  1  1    male  26.0  0    0  30.0000  C          C
# 889  0  3    male  32.0  0    0   7.7500  Q        NaN
#
# [890 rows x 9 columns]

# %% [markdown]
# #### 헤더를 없애기(헤더는 숫자로 대체됨)

# %%
pd.read_csv("./Course_Materials_Part2/Course_Materials_Part2/Video_Lecture_NBs/titanic.csv", header = None)
# Out:
#             0       1       2     3      4      5        6         7     8
# 0    survived  pclass     sex   age  sibsp  parch     fare  embarked  deck
# 1           0       3    male  22.0      1      0     7.25         S   NaN
# 2           1       1  female  38.0      1      0  71.2833         C     C
# 3           1       3  female  26.0      0      0    7.925         S   NaN
# 4           1       1  female  35.0      1      0     53.1         S     C
# ..        ...     ...     ...   ...    ...    ...      ...       ...   ...
# 887         0       2    male  27.0      0      0     13.0         S   NaN
# 888         1       1  female  19.0      0      0     30.0         S     B
# 889         0       3  female   NaN      1      2    23.45         S   NaN
# 890         1       1    male  26.0      0      0     30.0         C     C
# 891         0       3    male  32.0      0      0     7.75         Q   NaN
#
# [892 rows x 9 columns]

# %% [markdown]
# #### 헤더명 지정해서 불러오기

# %%
pd.read_csv("./Course_Materials_Part2/Course_Materials_Part2/Video_Lecture_NBs/titanic.csv",header=0
            ,names = ["alive", "class", "gender", "age", "silbsp", "parch", "price", "emb", "deck"])
# Out:
#      alive  class  gender   age  silbsp  parch    price emb deck
# 0        0      3    male  22.0       1      0   7.2500   S  NaN
# 1        1      1  female  38.0       1      0  71.2833   C    C
# 2        1      3  female  26.0       0      0   7.9250   S  NaN
# 3        1      1  female  35.0       1      0  53.1000   S    C
# 4        0      3    male  35.0       0      0   8.0500   S  NaN
# ..     ...    ...     ...   ...     ...    ...      ...  ..  ...
# 886      0      2    male  27.0       0      0  13.0000   S  NaN
# 887      1      1  female  19.0       0      0  30.0000   S    B
# 888      0      3  female   NaN       1      2  23.4500   S  NaN
# 889      1      1    male  26.0       0      0  30.0000   C    C
# 890      0      3    male  32.0       0      0   7.7500   Q  NaN
#
# [891 rows x 9 columns]

# %% [markdown]
# #### 특정 칼럼만 사용하기

# %%
titanic = pd.read_csv("./Course_Materials_Part2/Course_Materials_Part2/Video_Lecture_NBs/titanic.csv", header=0, index_col="pclass", usecols=["survived", "pclass", "sex", "age"])

# %%
titanic.head()
# Out:
#         survived     sex   age
# pclass
# 3              0    male  22.0
# 1              1  female  38.0
# 3              1  female  26.0
# 1              1  female  35.0
# 3              0    male  35.0

# %% [markdown]
# #### 이미 불러온 데이터의 칼럼이름 바꾸기

# %%
titanic.columns = ["alive", "gender", "age"]

# %%
titanic.index.name = "class"

# %%
titanic.head()
# Out:
#        alive  gender   age
# class
# 3          0    male  22.0
# 1          1  female  38.0
# 3          1  female  26.0
# 1          1  female  35.0
# 3          0    male  35.0

# %% [markdown]
# ### importing CSV Files - 정리되지 않은 데이터

# %%
import pandas as pd

# %%
pd.read_csv("./Course_Materials_Part2/Course_Materials_Part2/Video_Lecture_NBs/titanic_raw.csv")
# Out:
#                                               This       is       the  \
# It   contains  all       passengers  that     were   aboard       the
# the  tragic    disaster  occured     in        the     year        19
# 0   0         3         male        22.0         1        0     $7.25
# 1   1         1         female      38.0         1        0  $71.2833
# 2   1         3         female      26.0         0        0    $7.925
# ...                                            ...      ...       ...
# 891 0         2         male        24.0         0        0     $10.5
# 892 0         3         male        34.0         1        1     $14.4
# 893 0         3         male        36.0         0        0   $7.8958
# End  of        the       Dataset                                  NaN
# Get  more      Datasets  on          Kaggle      .      com       NaN
#
#                                               Titanic  Dataset.
# ...

# %% [markdown]
# #### 시작행, 끝나는 행, 칼럼 이름 지정

# %%
col_names = ["Survived", "Class", "Gender", "Age", "SipSp", "ParCh", "Fare", "Emb", "Deck"]

# %%
titanic = pd.read_csv("./Course_Materials_Part2/Course_Materials_Part2/Video_Lecture_NBs/titanic_raw.csv", skiprows=3, skipfooter=2, header=None, names = col_names)
# Out:
# C:\Users\skygg\AppData\Local\Temp\ipykernel_21400\3606197881.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   titanic = pd.read_csv("./Course_Materials_Part2/Course_Materials_Part2/Video_Lecture_NBs/titanic_raw.csv", skiprows=3, skipfooter=2, header=None, names = col_names)

# %%
titanic.head()
# Out:
#   Survived  Class  Gender   Age  SipSp  ParCh      Fare Emb Deck
# 0        0      3    male  22.0      1      0     $7.25   S  NaN
# 1        1      1  female  38.0      1      0  $71.2833   C    C
# 2        1      3  female  26.0      0      0    $7.925   S  NaN
# 3        1      1  female  35.0      1      0     $53.1   S    C
# 4        0      3    male  35.0      0      0     $8.05   S  NaN

# %% [markdown]
# 판다스는 기본적으로 레인지 인덱스(Unnamed: 0)를 추가 생성하므로 index = False를 추가해야한다.

# %%
titanic.to_csv("titanic_imp.csv", index=False)

# %%
# 판다스는 기본적으로 레인지 인덱스를 추가 생성한다
pd.read_csv("titanic_imp.csv")
# Out:
#     Survived  Class  Gender   Age  SipSp  ParCh      Fare Emb Deck
# 0          0      3    male  22.0      1      0     $7.25   S  NaN
# 1          1      1  female  38.0      1      0  $71.2833   C    C
# 2          1      3  female  26.0      0      0    $7.925   S  NaN
# 3          1      1  female  35.0      1      0     $53.1   S    C
# 4          0      3    male  35.0      0      0     $8.05   S  NaN
# ..       ...    ...     ...   ...    ...    ...       ...  ..  ...
# 889        1      1    male  26.0      0      0     $30.0   C    C
# 890        0      3    male  32.0      0      0     $7.75   Q  NaN
# 891        0      2    male  24.0      0      0     $10.5   S  NaN
# 892        0      3    male  34.0      1      1     $14.4   S  NaN
# 893        0      3    male  36.0      0      0   $7.8958   S  NaN
#
# [894 rows x 9 columns]

# %% [markdown]
# ### importing excel Files

# %%
import pandas as pd

# %%
sales = pd.read_excel("./Course_Materials_Part2/Course_Materials_Part2/Video_Lecture_NBs/sales.xls")

# %%
sales
# Out:
#   Unnamed: 0      City Country  Sales  Bonus
# 0       Mike  New York     USA     25   2.50
# 1        Jim    Boston     USA     43   4.30
# 2     Steven    London      UK     76   7.60
# 3        Joe    Madrid   Spain     12   1.80
# 4        Tom     Paris  France     89  13.35

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5 non-null      object
#  1   City        5 non-null      object
#  2   Country     5 non-null      object
#  3   Sales       5 non-null      int64
#  4   Bonus       5 non-null      float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 328.0+ bytes

# %%
pd.read_excel("./Course_Materials_Part2/Course_Materials_Part2/Video_Lecture_NBs/sales.xls", index_col=0, header = 0)
# Out:
#             City Country  Sales  Bonus
# Mike    New York     USA     25   2.50
# Jim       Boston     USA     43   4.30
# Steven    London      UK     76   7.60
# Joe       Madrid   Spain     12   1.80
# Tom        Paris  France     89  13.35

# %%
pd.read_excel("./Course_Materials_Part2/Course_Materials_Part2/Video_Lecture_NBs/sales.xls", index_col=0, header = 1)
# Out:
#        New York     USA  25    2.5
# Mike
# Jim      Boston     USA  43   4.30
# Steven   London      UK  76   7.60
# Joe      Madrid   Spain  12   1.80
# Tom       Paris  France  89  13.35

# %%
pd.read_excel("./Course_Materials_Part2/Course_Materials_Part2/Video_Lecture_NBs/sales.xls", index_col=0, header = 0, names = ["Name", "Loc_City", "Loc_Country", "Revenue", "Add_Comp"])
# Out:
#         Loc_City Loc_Country  Revenue  Add_Comp
# Name
# Mike    New York         USA       25      2.50
# Jim       Boston         USA       43      4.30
# Steven    London          UK       76      7.60
# Joe       Madrid       Spain       12      1.80
# Tom        Paris      France       89     13.35

# %%
pd.read_excel("./Course_Materials_Part2/Course_Materials_Part2/Video_Lecture_NBs/sales.xls", index_col=0, header = 0, usecols="A:C")
# Out:
#             City Country
# Mike    New York     USA
# Jim       Boston     USA
# Steven    London      UK
# Joe       Madrid   Spain
# Tom        Paris  France

# %%
pd.read_excel("./Course_Materials_Part2/Course_Materials_Part2/Video_Lecture_NBs/sales.xls", index_col=0, header = 0, usecols="C:E")
# Out:
#          Sales  Bonus
# Country
# USA         25   2.50
# USA         43   4.30
# UK          76   7.60
# Spain       12   1.80
# France      89  13.35

# %%
pd.read_excel("./Course_Materials_Part2/Course_Materials_Part2/Video_Lecture_NBs/sales.xls", index_col=0, header = 0, usecols="A,C:E")
# Out:
#        Country  Sales  Bonus
# Mike       USA     25   2.50
# Jim        USA     43   4.30
# Steven      UK     76   7.60
# Joe      Spain     12   1.80
# Tom     France     89  13.35

# %%
pd.read_excel("./Course_Materials_Part2/Course_Materials_Part2/Video_Lecture_NBs/sales.xls", index_col=0, header = 0, usecols=":C")
# Out:
#             City Country
# Mike    New York     USA
# Jim       Boston     USA
# Steven    London      UK
# Joe       Madrid   Spain
# Tom        Paris  France

# %%
pd.read_excel("./Course_Materials_Part2/Course_Materials_Part2/Video_Lecture_NBs/sales.xls", index_col=0, header = 0, usecols="C:")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [58], in <cell line: 1>()
# ----> 1 pd.read_excel("./Course_Materials_Part2/Course_Materials_Part2/Video_Lecture_NBs/sales.xls", index_col=0, header = 0, usecols="C:")
#
# File ~\anaconda3\envs\daitgirls6\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
pd.read_excel("./Course_Materials_Part2/Course_Materials_Part2/Video_Lecture_NBs/sales.xls", index_col=0, header = 0, usecols=[0,3,4])
# Out:
#         Sales  Bonus
# Mike       25   2.50
# Jim        43   4.30
# Steven     76   7.60
# Joe        12   1.80
# Tom        89  13.35

# %%
pd.read_excel("./Course_Materials_Part2/Course_Materials_Part2/Video_Lecture_NBs/sales.xls", index_col=0, header = 0, usecols=2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [60], in <cell line: 1>()
# ----> 1 pd.read_excel("./Course_Materials_Part2/Course_Materials_Part2/Video_Lecture_NBs/sales.xls", index_col=0, header = 0, usecols=2)
#
# File ~\anaconda3\envs\daitgirls6\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
pd.read_excel("./Course_Materials_Part2/Course_Materials_Part2/Video_Lecture_NBs/sales.xls", index_col=0, header = 0, usecols=["City","Sales" ])
# Out:
#           Sales
# City
# New York     25
# Boston       43
# London       76
# Madrid       12
# Paris        89

# %% [markdown]
# ### importing excel Files - 정제되지 않은 엑셀 파일

# %%
import pandas as pd

# %%
pd.read_excel("./Course_Materials_Part2/Course_Materials_Part2/Video_Lecture_NBs/summer_raw.xls")
# Out:
#   Unnamed: 0      City Country  Sales  Bonus
# 0       Mike  New York     USA     25    2.5
# 1        Jim    Boston     USA     43    4.3
# 2     Steven    London      UK     76    7.6
# 3        Joe    Madrid   Spain     12    1.8
# 4        Tom     Paris  France     89   13.4

# %%
pd.read_excel("./Course_Materials_Part2/Course_Materials_Part2/Video_Lecture_NBs/summer_raw.xls", sheet_name="summer")
# Out:
#        Unnamed: 0  Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0             NaN         NaN         NaN        NaN        NaN        NaN
# 1             NaN         NaN         NaN       Year       City      Sport
# 2             NaN         NaN         0.0       1896     Athens   Aquatics
# 3             NaN         NaN         1.0       1896     Athens   Aquatics
# 4             NaN         NaN         2.0       1896     Athens   Aquatics
# ...           ...         ...         ...        ...        ...        ...
# 31167         NaN         NaN     31165.0       2012     London  Wrestling
# 31168         NaN         NaN     31166.0       2012     London  Wrestling
# 31169         NaN         NaN     31167.0       2012     London  Wrestling
# 31170         NaN         NaN     31168.0       2012     London  Wrestling
# 31171         NaN         NaN     31169.0       2012     London  Wrestling
#
# ...

# %%
pd.read_excel("./Course_Materials_Part2/Course_Materials_Part2/Video_Lecture_NBs/summer_raw.xls", sheet_name="summer", skiprows=2)
# Out:
#        Unnamed: 0  Unnamed: 1  Unnamed: 2  Year    City      Sport  \
# 0             NaN         NaN           0  1896  Athens   Aquatics
# 1             NaN         NaN           1  1896  Athens   Aquatics
# 2             NaN         NaN           2  1896  Athens   Aquatics
# 3             NaN         NaN           3  1896  Athens   Aquatics
# 4             NaN         NaN           4  1896  Athens   Aquatics
# ...           ...         ...         ...   ...     ...        ...
# 31165         NaN         NaN       31165  2012  London  Wrestling
# 31166         NaN         NaN       31166  2012  London  Wrestling
# 31167         NaN         NaN       31167  2012  London  Wrestling
# 31168         NaN         NaN       31168  2012  London  Wrestling
# 31169         NaN         NaN       31169  2012  London  Wrestling
#
#                 Discipline                 Athlete Name Country Gender  \
# 0                 Swimming               HAJOS, Alfred      HUN    Men
# ...

# %%
# 엑셀에 있는 레인지 인덱스를 인식 못함
pd.read_excel("./Course_Materials_Part2/Course_Materials_Part2/Video_Lecture_NBs/summer_raw.xls", sheet_name="summer", skiprows=2, usecols="C:L")
# Out:
#        Unnamed: 2  Year    City      Sport           Discipline  \
# 0               0  1896  Athens   Aquatics             Swimming
# 1               1  1896  Athens   Aquatics             Swimming
# 2               2  1896  Athens   Aquatics             Swimming
# 3               3  1896  Athens   Aquatics             Swimming
# 4               4  1896  Athens   Aquatics             Swimming
# ...           ...   ...     ...        ...                  ...
# 31165       31165  2012  London  Wrestling  Wrestling Freestyle
# 31166       31166  2012  London  Wrestling  Wrestling Freestyle
# 31167       31167  2012  London  Wrestling  Wrestling Freestyle
# 31168       31168  2012  London  Wrestling  Wrestling Freestyle
# 31169       31169  2012  London  Wrestling  Wrestling Freestyle
#
#                       Athlete Name Country Gender                       Event  \
# 0                   HAJOS, Alfred      HUN    Men              100M Freestyle
# ...

# %%
pd.read_excel("./Course_Materials_Part2/Course_Materials_Part2/Video_Lecture_NBs/summer_raw.xls", sheet_name="summer", skiprows=2, usecols="D:L")
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31165  2012  London  Wrestling  Wrestling Freestyle
# 31166  2012  London  Wrestling  Wrestling Freestyle
# 31167  2012  London  Wrestling  Wrestling Freestyle
# 31168  2012  London  Wrestling  Wrestling Freestyle
# 31169  2012  London  Wrestling  Wrestling Freestyle
#
#                       Athlete Name Country Gender                       Event  \
# 0                   HAJOS, Alfred      HUN    Men              100M Freestyle
# 1                HERSCHMANN, Otto      AUT    Men              100M Freestyle
# 2               DRIVAS, Dimitrios      GRE    Men  100M Freestyle For Sailors
# ...

# %%
summer = pd.read_excel("./Course_Materials_Part2/Course_Materials_Part2/Video_Lecture_NBs/summer_raw.xls", sheet_name="summer", skiprows=2, usecols="D:L")

# %%
summer.head()
# Out:
#    Year    City     Sport Discipline          Athlete Name Country Gender  \
# 0  1896  Athens  Aquatics   Swimming        HAJOS, Alfred      HUN    Men
# 1  1896  Athens  Aquatics   Swimming     HERSCHMANN, Otto      AUT    Men
# 2  1896  Athens  Aquatics   Swimming    DRIVAS, Dimitrios      GRE    Men
# 3  1896  Athens  Aquatics   Swimming   Malokinis, Ioannis      GRE    Men
# 4  1896  Athens  Aquatics   Swimming   Chasapis, Spiridon      GRE    Men
#
#                         Event       Medal
# 0              100M Freestyle  Gold Medal
# 1              100M Freestyle      Silver
# 2  100M Freestyle For Sailors      Bronze
# 3  100M Freestyle For Sailors  Gold Medal
# 4  100M Freestyle For Sailors      Silver

# %%
summer.tail()
# Out:
#        Year    City      Sport           Discipline  \
# 31165  2012  London  Wrestling  Wrestling Freestyle
# 31166  2012  London  Wrestling  Wrestling Freestyle
# 31167  2012  London  Wrestling  Wrestling Freestyle
# 31168  2012  London  Wrestling  Wrestling Freestyle
# 31169  2012  London  Wrestling  Wrestling Freestyle
#
#                       Athlete Name Country Gender     Event   Medal
# 31165          JANIKOWSKI, Damian      POL    Men  Wg 84 KG  Bronze
# 31166   REZAEI, Ghasem Gholamreza      IRI    Men  Wg 96 KG    Gold
# 31167              TOTROV, Rustam      RUS    Men  Wg 96 KG  Silver
# 31168           ALEKSANYAN, Artur      ARM    Men  Wg 96 KG  Bronze
# 31169              LIDBERG, Jimmy      SWE    Men  Wg 96 KG  Bronze

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31170 entries, 0 to 31169
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          31170 non-null  int64
#  1   City          31170 non-null  object
#  2   Sport         31170 non-null  object
#  3   Discipline    31170 non-null  object
#  4   Athlete Name  31170 non-null  object
#  5   Country       31166 non-null  object
#  6   Gender        31170 non-null  object
#  7   Event         31170 non-null  object
#  8   Medal         31170 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB

# %%
summer.to_csv("summer_imp.csv", index=False)

# %%
summer.to_excel("summer_imp.xls")
# Out:
# C:\Users\skygg\AppData\Local\Temp\ipykernel_21400\467404130.py:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   summer.to_excel("summer_imp.xls")

# %%
pd.read_csv("summer_imp.csv")
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31165  2012  London  Wrestling  Wrestling Freestyle
# 31166  2012  London  Wrestling  Wrestling Freestyle
# 31167  2012  London  Wrestling  Wrestling Freestyle
# 31168  2012  London  Wrestling  Wrestling Freestyle
# 31169  2012  London  Wrestling  Wrestling Freestyle
#
#                       Athlete Name Country Gender                       Event  \
# 0                   HAJOS, Alfred      HUN    Men              100M Freestyle
# 1                HERSCHMANN, Otto      AUT    Men              100M Freestyle
# 2               DRIVAS, Dimitrios      GRE    Men  100M Freestyle For Sailors
# ...

# %% [markdown]
# ### importing html

# %%
import pandas as pd

# %%
url = "https://en.wikipedia.org/wiki/1976_Summer_Olympics_medal_table"

# %%
pd.read_html(url)[4]
# Out:
#                       vte Olympic Games medal tables  \
# 0  Olympic medal All-time Olympic Games medal tab...
# 1                               Summer Olympic Games
# 2                               Winter Olympic Games
# 3  Lists of Olympic medalists List of stripped Ol...
#
#                     vte Olympic Games medal tables.1
# 0  Olympic medal All-time Olympic Games medal tab...
# 1  1896 1900 1904 1908 1912 1920 1924 1928 1932 1...
# 2  1924 1928 1932 1936 1948 1952 1956 1960 1964 1...
# 3  Lists of Olympic medalists List of stripped Ol...

# %%
wik_1976 = pd.read_html(url)[2]

# %%
wik_1976.head()
# Out:
#   Rank            NOC  Gold  Silver  Bronze  Total
# 0    1   Soviet Union    49      41      35    125
# 1    2   East Germany    40      25      25     90
# 2    3  United States    34      35      25     94
# 3    4   West Germany    10      12      17     39
# 4    5          Japan     9       6      10     25

# %%
wik_1976.tail()
# Out:
#                    Rank                  NOC  Gold  Silver  Bronze  Total
# 37                   37              Bermuda     0       0       1      1
# 38                   37             Pakistan     0       0       1      1
# 39                   37          Puerto Rico     0       0       1      1
# 40                   37             Thailand     0       0       1      1
# 41  Totals (41 entries)  Totals (41 entries)   198     199     216    613

# %%
wik_1976.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rank    42 non-null     object
#  1   NOC     42 non-null     object
#  2   Gold    42 non-null     int64
#  3   Silver  42 non-null     int64
#  4   Bronze  42 non-null     int64
#  5   Total   42 non-null     int64
# dtypes: int64(4), object(2)
# memory usage: 2.1+ KB

# %%
url2 = "https://en.wikipedia.org/wiki/1996_Summer_Olympics_medal_table"

# %%
pd.read_html(url2)
# Out:
# [           1996 Summer Olympics medals        1996 Summer Olympics medals.1
#  0                             Location               Atlanta, United States
#  1                           Highlights                           Highlights
#  2                     Most gold medals                   United States (44)
#  3                    Most total medals                  United States (101)
#  4  ← 1992 Olympics medal tables 2000 →  ← 1992 Olympics medal tables 2000 →,
#                                                     0
#  0                                Part of a series on
#  1                               1996 Summer Olympics
#  2  Bid process (bid details) Venues Marketing (ma...
#  3  .mw-parser-output .navbar{display:inline;font-...,
#                     Rank               Nation  Gold  Silver  Bronze  Total
#  0                     1       United States*    44      32      25    101
#  1                     2               Russia    26      21      16     63
# ...

# %%
wik_1996 = pd.read_html(url2)[2]

# %%
wik_1996.head()
# Out:
#   Rank          Nation  Gold  Silver  Bronze  Total
# 0    1  United States*    44      32      25    101
# 1    2          Russia    26      21      16     63
# 2    3         Germany    20      18      27     65
# 3    4           China    16      22      12     50
# 4    5          France    15       7      15     37

# %%
wik_1996.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rank    80 non-null     object
#  1   Nation  80 non-null     object
#  2   Gold    80 non-null     int64
#  3   Silver  80 non-null     int64
#  4   Bronze  80 non-null     int64
#  5   Total   80 non-null     int64
# dtypes: int64(4), object(2)
# memory usage: 3.9+ KB

# %%
wik_1976.to_csv("wik_1976.csv", index=False)
wik_1996.to_csv("wik_1996.csv", index=False)
